# %%
#ADTK库
from adtk.data import validate_series
from adtk.visualization import plot
from adtk.detector import SeasonalAD
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('turb1.csv')
wspd = data[['Day','Tmstamp','Wspd']].fillna(0)
wspd['date'] = pd.to_datetime(wspd['Day'].astype(str) + ' ' + data['Tmstamp'], format='%j %H:%M')
wspd.index = wspd['date']
print(wspd.shape)
# Out:
# (35280, 4)

# %%
series = validate_series(wspd[0:144])
detector = SeasonalAD()
anomalies = detector.fit_detect(series)
plot(series,anomalies)
# Out:
# c:\Users\92469\miniconda3\envs\thuml\lib\site-packages\statsmodels\tsa\stattools.py:693: RuntimeWarning: invalid value encountered in divide
#   acf = avf[: nlags + 1] / avf[0]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 series = validate_series(wspd[0:144])
#       2 detector = SeasonalAD()
# ----> 3 anomalies = detector.fit_detect(series)
#       4 plot(series,anomalies)
#
# File c:\Users\92469\miniconda3\envs\thuml\lib\site-packages\adtk\_detector_base.py:247, in _TrainableUnivariateDetector.fit_predict(self, ts, return_list)
#     205 def fit_predict(
#     206     self, ts: Union[pd.Series, pd.DataFrame], return_list: bool = False
#     207 ) -> Union[
#    (...)
#     213     ],
#     214 ]:
#     215     """Train the detector and detect anomalies from the time series used
#     216     for training.
#     217
#    (...)
#     245
#     246     """
# --> 247     self.fit(ts)
#     248     return self.detect(ts, return_list=return_list)
#
# File c:\Users\92469\miniconda3\envs\thuml\lib\site-packages\adtk\_detector_base.py:152, in _TrainableUnivariateDetector.fit(self, ts)
#     141 def fit(self, ts: Union[pd.Series, pd.DataFrame]) -> None:
#     142     """Train the detector with given time series.
#     143
#     144     Parameters
#    (...)
#     150
#     151     """
# --> 152     self._fit(ts)
#
# File c:\Users\92469\miniconda3\envs\thuml\lib\site-packages\adtk\_base.py:174, in _TrainableUnivariateModel._fit(self, ts)
#     172     # fit model for each column
#     173     for col in df.columns:
# --> 174         self._models[col].fit(df[col])
#     175     self._fitted = 2
#     176 else:
#
# File c:\Users\92469\miniconda3\envs\thuml\lib\site-packages\adtk\_detector_base.py:152, in _TrainableUnivariateDetector.fit(self, ts)
#     141 def fit(self, ts: Union[pd.Series, pd.DataFrame]) -> None:
#     142     """Train the detector with given time series.
#     143
#     144     Parameters
#    (...)
#     150
#     151     """
# --> 152     self._fit(ts)
#
# File c:\Users\92469\miniconda3\envs\thuml\lib\site-packages\adtk\_base.py:154, in _TrainableUnivariateModel._fit(self, ts)
#     152 if isinstance(ts, pd.Series):
#     153     s = ts.copy()  # type: pd.Series
# --> 154     self._fit_core(s)
#     155     self._fitted = 1
#     156 elif isinstance(ts, pd.DataFrame):
#
# File c:\Users\92469\miniconda3\envs\thuml\lib\site-packages\adtk\detector\_detector_1d.py:1156, in SeasonalAD._fit_core(self, s)
#    1154 def _fit_core(self, s: pd.Series) -> None:
#    1155     self._sync_params()
# -> 1156     self.pipe_.fit(s)
#    1157     self.freq_ = self.pipe_.steps["deseasonal_residual"]["model"].freq_
#    1158     self.seasonal_ = self.pipe_.steps["deseasonal_residual"][
#    1159         "model"
#    1160     ].seasonal_
#
# File c:\Users\92469\miniconda3\envs\thuml\lib\site-packages\adtk\pipe\_pipe.py:893, in Pipenet.fit(self, ts, skip_fit, return_intermediate)
#     891         results.update({step_name: step["model"].predict(input)})
#     892     else:
# --> 893         results.update({step_name: step["model"].fit_predict(input)})
#     895 # return intermediate results
#     896 if return_intermediate:
#
# File c:\Users\92469\miniconda3\envs\thuml\lib\site-packages\adtk\_transformer_base.py:96, in _TrainableUnivariateTransformer.fit_predict(self, ts)
#      76 def fit_predict(
#      77     self, ts: Union[pd.Series, pd.DataFrame]
#      78 ) -> Union[pd.Series, pd.DataFrame]:
#      79     """Train the transformer, and tranform the time series used for
#      80     training.
#      81
#    (...)
#      94
#      95     """
# ---> 96     self.fit(ts)
#      97     return self.predict(ts)
#
# File c:\Users\92469\miniconda3\envs\thuml\lib\site-packages\adtk\_transformer_base.py:49, in _TrainableUnivariateTransformer.fit(self, ts)
#      38 def fit(self, ts: Union[pd.Series, pd.DataFrame]) -> None:
#      39     """Train the transformer with given time series.
#      40
#      41     Parameters
#    (...)
#      47
#      48     """
# ---> 49     self._fit(ts)
#
# File c:\Users\92469\miniconda3\envs\thuml\lib\site-packages\adtk\_base.py:154, in _TrainableUnivariateModel._fit(self, ts)
#     152 if isinstance(ts, pd.Series):
#     153     s = ts.copy()  # type: pd.Series
# --> 154     self._fit_core(s)
#     155     self._fitted = 1
#     156 elif isinstance(ts, pd.DataFrame):
#
# File c:\Users\92469\miniconda3\envs\thuml\lib\site-packages\adtk\transformer\_transformer_1d.py:711, in ClassicSeasonalDecomposition._fit_core(self, s)
#     709 # get seasonal freq
#     710 if self.freq is None:
# --> 711     identified_freq = _identify_seasonal_period(s)
#     712     if identified_freq is None:
#     713         raise Exception("Could not find significant seasonality.")
#
# File c:\Users\92469\miniconda3\envs\thuml\lib\site-packages\adtk\transformer\_transformer_1d.py:861, in _identify_seasonal_period(s, low_autocorr, high_autocorr)
#     858     raise ValueError("The time steps are not constant. ")
#     860 autocorr = acf(s, nlags=len(s), fft=False)
# --> 861 cutPos = np.argwhere(autocorr >= low_autocorr)[0][0]
#     862 diff_autocorr = np.diff(autocorr[cutPos:])
#     863 high_autocorr_peak_pos = (
#     864     cutPos
#     865     + 1
#    (...)
#     870     ).flatten()
#     871 )
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
